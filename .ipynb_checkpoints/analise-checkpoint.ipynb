# %% [markdown]
# # Tentativa de análise estatística inferencial de dados econômicos do Brasil
#
# ### Info:
# - https://www.ibge.gov.br/explica/inflacao.php
#
# ### Dados analizados:
# - https://sidra.ibge.gov.br/tabela/1737
# - https://dados.gov.br/dataset/dolar-americano-usd-todos-os-boletins-diarios

# %%
# importação das bibliotecas principais
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# #### Tratamento do arquivo original para um arquivo csv (executado apenas uma vez):

# %%
pd.read_csv('tabela1737.tsv', sep='\t', names=['Mês', 'IPCA - Variação mensal']).replace('...', np.nan).to_csv('IPCA-Variação_mensal.csv', index=False)

# %%
data = pd.read_csv('Cotação do Dólar por período.csv')
f = lambda x: float(x.replace(',', '.'))
g = lambda x: datetime.strftime(datetime.strptime(x.split(' ')[0], '%Y-%m-%d'), '%d/%m/%Y')
data['cotacaoCompra'] = data['cotacaoCompra'].apply(f)
data['cotacaoVenda'] = data['cotacaoVenda'].apply(f)
data['dataHoraCotacao'] = data['dataHoraCotacao'].apply(g)
data.rename(columns={'cotacaoCompra':'compra', 'cotacaoVenda':'venda', 'dataHoraCotacao':'data'}).to_csv('Cotação_dólar.csv', index=False)

# %% [markdown]
# ### 1.0 Importar dados:
#
# #### Para facilitar a análise os dados serão armazenados no formato de vetor (numpy array).
#  - A variável `month` armazena as datas para ter referência.

# %%
df0 = pd.read_csv('IPCA-Variação_mensal.csv')
df0
# Out:
#                 Mês  IPCA - Variação mensal
# 0      janeiro 1980                    6.62
# 1    fevereiro 1980                    4.62
# 2        março 1980                    6.04
# 3        abril 1980                    5.29
# 4         maio 1980                    5.70
# ..              ...                     ...
# 494      março 2021                    0.93
# 495      abril 2021                    0.31
# 496       maio 2021                    0.83
# 497      junho 2021                    0.53
# 498      julho 2021                    0.96
#
# [499 rows x 2 columns]

# %%
month = []
for date in set(df0['Mês']):
    m, y = date.split(' ')
    m = {'janeiro':'01', 'fevereiro':'02', 'março':'03', 'abril':'04',
     'maio':'05', 'junho':'06', 'julho':'07', 'agosto':'08', 
     'setembro':'09', 'outubro':'10', 'novembro':'11', 'dezembro':'12'}[m]
    month.append(datetime.strptime(m+y, '%m%Y'))
month.sort()

ipca_data = df0['IPCA - Variação mensal'].to_numpy()
print('Formato da matriz: ', ipca_data.shape)
print('Datas:')
for i, var in enumerate(month): 
    month[i] = datetime.strftime(var, '%m/%Y')
    print(i, month[i])
# Out:
# Formato da matriz:  (499,)
# Datas:
# 0 01/1980
# 1 02/1980
# 2 03/1980
# 3 04/1980
# 4 05/1980
# 5 06/1980
# 6 07/1980
# 7 08/1980
# 8 09/1980
# 9 10/1980
# 10 11/1980
# 11 12/1980
# 12 01/1981
# 13 02/1981
# 14 03/1981
# 15 04/1981
# 16 05/1981
# 17 06/1981
# 18 07/1981
# 19 08/1981
# 20 09/1981
# 21 10/1981
# 22 11/1981
# 23 12/1981
# 24 01/1982
# 25 02/1982
# 26 03/1982
# 27 04/1982
# 28 05/1982
# 29 06/1982
# 30 07/1982
# 31 08/1982
# 32 09/1982
# 33 10/1982
# 34 11/1982
# 35 12/1982
# 36 01/1983
# 37 02/1983
# 38 03/1983
# 39 04/1983
# 40 05/1983
# 41 06/1983
# 42 07/1983
# 43 08/1983
# 44 09/1983
# 45 10/1983
# 46 11/1983
# 47 12/1983
# 48 01/1984
# 49 02/1984
# 50 03/1984
# 51 04/1984
# 52 05/1984
# 53 06/1984
# 54 07/1984
# 55 08/1984
# 437 06/2016
# 438 07/2016
# 439 08/2016
# 440 09/2016
# 441 10/2016
# 442 11/2016
# 443 12/2016
# 444 01/2017
# 445 02/2017
# 446 03/2017
# 447 04/2017
# 448 05/2017
# 449 06/2017
# 450 07/2017
# 451 08/2017
# 452 09/2017
# 453 10/2017
# 454 11/2017
# 455 12/2017
# 456 01/2018
# 457 02/2018
# 458 03/2018
# 459 04/2018
# 460 05/2018
# 461 06/2018
# 462 07/2018
# 463 08/2018
# 464 09/2018
# 465 10/2018
# 466 11/2018
# 467 12/2018
# 468 01/2019
# 469 02/2019
# 470 03/2019
# 471 04/2019
# 472 05/2019
# 473 06/2019
# 474 07/2019
# 475 08/2019
# 476 09/2019
# 477 10/2019
# 478 11/2019
# 479 12/2019
# 480 01/2020
# 481 02/2020
# 482 03/2020
# 483 04/2020
# 484 05/2020
# 485 06/2020
# 486 07/2020
# 487 08/2020
# 488 09/2020
# 489 10/2020
# 490 11/2020
# 491 12/2020
# 492 01/2021
# 493 02/2021
# 494 03/2021
# 495 04/2021
# 496 05/2021
# 497 06/2021
# 498 07/2021

# %%
x, xt = [], []
for t in range(0, ipca_data.shape[0], 120):
    x.append(t)
    xt.append(month[t])

i = 3
plt.figure(figsize=(14, 5))
plt.title('IPCA - Variação mensal')
plt.vlines(month.index('02/1986'), 0, 80, color='orange', linestyles='dashed', label='Plano cruzado')
plt.vlines(month.index('01/1990'), 0, 80, color='r', linestyles='dashed', label='Plano color')
plt.vlines(month.index('03/1994'), 0, 80, color='g', linestyles='dashed', label='Plano real')
plt.plot(ipca_data)
plt.xticks(x, xt)
plt.legend()
plt.show()

# %%
df1 = pd.read_csv('Cotação_dólar.csv')
df1
# Out:
#         compra     venda        data
# 0     761.4900  765.3000  02/01/1989
# 1     770.3600  774.2100  03/01/1989
# 2     779.3300  783.2300  04/01/1989
# 3     788.4100  792.3500  05/01/1989
# 4     797.5900  801.5800  06/01/1989
# ...        ...       ...         ...
# 8020    5.1620    5.1626  04/01/2021
# 8021    5.3263    5.3269  05/01/2021
# 8022    5.3176    5.3182  06/01/2021
# 8023    5.3427    5.3433  07/01/2021
# 8024    5.3677    5.3683  08/01/2021
#
# [8025 rows x 3 columns]

# %% [markdown]
# - **Analisando os dos valores da cotação, temos:**

# %%
difcot = df1['compra'] - df1['venda'] # diferença entre a cotação de compra e cotação de venda
print('Média:', np.mean(difcot))
print('Média da diferença absoluta:', np.mean(abs(difcot)))
print('Mediana:', np.median(difcot))
print('Variância:', np.var(difcot))
print('Desvio padrão:', np.std(difcot))
plt.plot(difcot)
plt.show()
# Out:
# Média: -0.06606620560747872
# Média da diferença absoluta: 0.06789200000000209
# Mediana: -0.0007999999999999119
# Variância: 2.4187198454647927
# Desvio padrão: 1.5552234069305904

# %% [markdown]
# Pode-se observar que os valores, no geral, tem pouca variação. Logo, para a análise, será tomado a média dos valores em torno da data. Para relacionar os dados será tomado a média mensal da cotação.

# %%
cot_data = []
val = []
f = lambda x: '/'.join(x.split('/')[1:])
cot_mes = f(df1.iloc[0]['data'])
for i in range(df1.shape[0]):
    if cot_mes in df1.iloc[i]['data']: val.append((df1.iloc[i]['compra'] + df1.iloc[i]['venda'])/2)
    else:
        cot_mes = f(df1.iloc[i]['data'])
        cot_data.append(np.mean(val))
        val = []

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,4))
axs[0].plot(cot_data)
axs[1].plot(range(100, len(cot_data)), cot_data[100:])
plt.show()
